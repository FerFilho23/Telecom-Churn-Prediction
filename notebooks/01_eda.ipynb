# %% [markdown]
# # 📊 Exploratory Data Analysis — Telco Customer Churn
#
# This notebook will explore and analyze the **IBM Telco Customer** dataset. The goal is to load, clean, and analyze the data for patterns and relationships that may influence customer satisfaction, resulting in customer churn.

# %%
from pathlib import Path

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ## Load the Dataset

# %%
data_dir = Path().resolve().parent / "data"
raw_data_path = data_dir / "raw" / "Telco_customer_churn.xlsx"
df = pd.read_excel(raw_data_path)

# %%
df.head().T
# Out:
#                                               0                      1  \
# CustomerID                           3668-QPYBK             9237-HQITU
# Count                                         1                      1
# Country                           United States          United States
# State                                California             California
# City                                Los Angeles            Los Angeles
# Zip Code                                  90003                  90005
# Lat Long                 33.964131, -118.272783  34.059281, -118.30742
# Latitude                              33.964131              34.059281
# Longitude                           -118.272783             -118.30742
# Gender                                     Male                 Female
# Senior Citizen                               No                     No
# Partner                                      No                     No
# ...

# %% [markdown]
# ## Clean Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
# Standardize column names
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.head().T
# Out:
#                                               0                      1  \
# customerid                           3668-QPYBK             9237-HQITU
# count                                         1                      1
# country                           United States          United States
# state                                California             California
# city                                Los Angeles            Los Angeles
# zip_code                                  90003                  90005
# lat_long                 33.964131, -118.272783  34.059281, -118.30742
# latitude                              33.964131              34.059281
# longitude                           -118.272783             -118.30742
# gender                                     Male                 Female
# senior_citizen                               No                     No
# partner                                      No                     No
# ...

# %%
# Convert total_charges to numeric, coercing errors to NaN
df.total_charges = pd.to_numeric(df.total_charges, errors="coerce")

# %%
df.total_charges.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: total_charges
# Non-Null Count  Dtype
# --------------  -----
# 7032 non-null   float64
# dtypes: float64(1)
# memory usage: 55.2 KB

# %%
df.isnull().sum()
# Out:
# customerid              0
# count                   0
# country                 0
# state                   0
# city                    0
# zip_code                0
# lat_long                0
# latitude                0
# longitude               0
# gender                  0
# senior_citizen          0
# partner                 0
# dependents              0
# tenure_months           0
# phone_service           0
# multiple_lines          0
# internet_service        0
# online_security         0
# online_backup           0
# device_protection       0
# tech_support            0
# streaming_tv            0
# streaming_movies        0
# contract                0
# paperless_billing       0
# payment_method          0
# monthly_charges         0
# total_charges          11
# churn_label             0
# churn_value             0
# churn_score             0
# cltv                    0
# churn_reason         5174
# dtype: int64

# %%
df[df.total_charges.isnull()]
# Out:
#       customerid  count        country       state            city  zip_code  \
# 2234  4472-LVYGI      1  United States  California  San Bernardino     92408
# 2438  3115-CZMZD      1  United States  California    Independence     93526
# 2568  5709-LVOEQ      1  United States  California       San Mateo     94401
# 2667  4367-NUYAO      1  United States  California       Cupertino     95014
# 2856  1371-DWPAZ      1  United States  California        Redcrest     95569
# 4331  7644-OMVMY      1  United States  California     Los Angeles     90029
# 4687  3213-VVOLG      1  United States  California        Sun City     92585
# 5104  2520-SGTTA      1  United States  California      Ben Lomond     95005
# 5719  2923-ARZLG      1  United States  California        La Verne     91750
# 6772  4075-WKNIU      1  United States  California            Bell     90201
# 6840  2775-SEFEE      1  United States  California      Wilmington     90744
#
# ...

# %%
# Calculate NA total_charges
df.total_charges = df.total_charges.fillna(df.monthly_charges * df.tenure_months)
df.isnull().sum()
# Out:
# customerid              0
# count                   0
# country                 0
# state                   0
# city                    0
# zip_code                0
# lat_long                0
# latitude                0
# longitude               0
# gender                  0
# senior_citizen          0
# partner                 0
# dependents              0
# tenure_months           0
# phone_service           0
# multiple_lines          0
# internet_service        0
# online_security         0
# online_backup           0
# device_protection       0
# tech_support            0
# streaming_tv            0
# streaming_movies        0
# contract                0
# paperless_billing       0
# payment_method          0
# monthly_charges         0
# total_charges           0
# churn_label             0
# churn_value             0
# churn_score             0
# cltv                    0
# churn_reason         5174
# dtype: int64

# %%
df[df.churn_reason.isnull()].churn_value.value_counts()
# Out:
# churn_value
# 0    5174
# Name: count, dtype: int64

# %%
df.churn_reason = df.churn_reason.fillna("No Churn")
df.isnull().sum()
# Out:
# customerid           0
# count                0
# country              0
# state                0
# city                 0
# zip_code             0
# lat_long             0
# latitude             0
# longitude            0
# gender               0
# senior_citizen       0
# partner              0
# dependents           0
# tenure_months        0
# phone_service        0
# multiple_lines       0
# internet_service     0
# online_security      0
# online_backup        0
# device_protection    0
# tech_support         0
# streaming_tv         0
# streaming_movies     0
# contract             0
# paperless_billing    0
# payment_method       0
# monthly_charges      0
# total_charges        0
# churn_label          0
# churn_value          0
# churn_score          0
# cltv                 0
# churn_reason         0
# dtype: int64

# %% [markdown]
# ## Analysis

# %%
df.nunique()
# Out:
# customerid           7043
# count                   1
# country                 1
# state                   1
# city                 1129
# zip_code             1652
# lat_long             1652
# latitude             1652
# longitude            1651
# gender                  2
# senior_citizen          2
# partner                 2
# dependents              2
# tenure_months          73
# phone_service           2
# multiple_lines          3
# internet_service        3
# online_security         3
# online_backup           3
# device_protection       3
# tech_support            3
# streaming_tv            3
# streaming_movies        3
# contract                3
# paperless_billing       2
# payment_method          4
# monthly_charges      1585
# total_charges        6531
# churn_label             2
# churn_value             2
# churn_score            85
# cltv                 3438
# churn_reason           21
# dtype: int64

# %%
df.groupby(["country", "state"]).size()
# Out:
# country        state
# United States  California    7043
# dtype: int64

# %% [markdown]
# ### Churn Rate

# %%
# Pie chart of churn rate
churn_counts = df.churn_label.value_counts()
fig = px.pie(
    names=churn_counts.keys(),
    values=churn_counts.values,
    title="Churn Label Distribution",
)
fig.show()

# %% [markdown]
# **26.5%** of customers churned — mild class imbalance. The goal is to know which type of customers are more likely to churn in order to predict future churning and take action to avoid it.

# %%
churn_reasons = df.churn_reason[df.churn_reason != "No Churn"].value_counts(
    ascending=False
)

fig = px.bar(
    x=churn_reasons.keys(),
    y=churn_reasons.values,
    color=churn_reasons.values,
    text=churn_reasons.values,
    title="Churn Reasons Distribution",
)

fig.update_layout(yaxis_title="Churn Reason", xaxis_title="Count")
fig.show()

# %% [markdown]
# **The graph shows that churn reasons can be divided into two main categories:**
#
# - **Internal** : those that are within the company's control, such as product quality, service quality, and price..
#
# - **External** : those that are outside of the company's control, such as competitor offerings and network reliability.
#
# **Actions that should to take:**
#
# The focus should be on improving product and service quality, and reducing prices, in order to address the top three churn reasons. It is also important to improve customer support, as this is major churn driver. The company should monitor competitor offerings and network reliability, and make adjustments as needed.

# %% [markdown]
# ### City

# %%
print(f"There are {df.city.nunique()} of unique cities")
# Out:
# There are 1129 of unique cities

# %%
city_churn = (
    df.groupby("city")
    .agg(churn_rate=("churn_value", "mean"), customer_count=("churn_value", "size"))
    .reset_index()
)

city_churn.head()
# Out:
#            city  churn_rate  customer_count
# 0        Acampo        0.75               4
# 1         Acton        0.00               4
# 2      Adelanto        0.20               5
# 3          Adin        0.50               4
# 4  Agoura Hills        0.40               5

# %%
# City counts
fig = px.bar(
    city_churn.sort_values("customer_count", ascending=False).head(20),
    x="city",
    y="customer_count",
    color="customer_count",
    text="customer_count",
    title="Customer Distribution by City",
)
fig.update_layout(yaxis_title="Number of Customers", xaxis_title="City")
fig.show()

# %% [markdown]
# - Customer base is heavily concentrated in a few large metropolitan areas (Los Angeles, San Diego, San Jose, Sacramento).
#
# - The majority of other cities have fewer than 30 customers, showing a strong class imbalance across cities.

# %%
# City Churn Rates
fig = px.bar(
    city_churn.sort_values("churn_rate", ascending=False).head(20),
    x="city",
    y="churn_rate",
    color="churn_rate",
    text="churn_rate",
    title="Churn Rate by City",
)
fig.update_layout(yaxis_title="Churn Rate", xaxis_title="City")
fig.show()

# %%
fig = px.scatter(
    city_churn,
    x="customer_count",
    y="churn_rate",
    size="churn_rate",
    labels="city",
    color="churn_rate",
    title="Churn Rate by City Customer Count",
)
fig.show()

# %% [markdown]
# - Several small towns (e.g., Fort Jones, Eldridge, Twain) display 100% churn rates, but these results stem from very small sample sizes.
#
# - Larger cities exhibit more moderate churn rates (< 40%), representing more stable and realistic values.

# %% [markdown]
# ### Latitude and Longitude

# %%
geo_churn = (
    df.groupby(["latitude", "longitude"])
    .agg(churn_rate=("churn_value", "mean"), customer_count=("churn_value", "size"))
    .reset_index()
)
geo_churn
# Out:
#        latitude   longitude  churn_rate  customer_count
# 0     32.555828 -117.040073        0.20               5
# 1     32.578103 -117.012975        0.40               5
# 2     32.579134 -117.119009        0.40               5
# 3     32.587557 -116.636816        0.00               5
# 4     32.605012 -116.975950        0.40               5
# ...         ...         ...         ...             ...
# 1647  41.924174 -123.260788        0.50               4
# 1648  41.932207 -120.135941        0.50               4
# 1649  41.949216 -122.050062        0.25               4
# 1650  41.950683 -124.097094        1.00               4
# 1651  41.962127 -122.527696        0.25               4
#
# [1652 rows x 4 columns]

# %%
# Churn Rate by Location
fig = px.scatter_map(
    geo_churn,
    lat="latitude",
    lon="longitude",
    color="churn_rate",
    zoom=5,
    title="📍 Churn Rate by Location",
)

fig.show()

# %%
# Customer Count by Location
fig = px.scatter_map(
    geo_churn,
    lat="latitude",
    lon="longitude",
    color="customer_count",
    zoom=5,
    title="📍 Customer Count by Location",
)

fig.show()

# %% [markdown]
# ### Tenure

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ## Save Processed Data

# %%
# Save cleaned data
df.to_excel(data_dir / "processed" / "telco_customer_churn_cleaned.xlsx", index=False)
